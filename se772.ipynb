# %%
import matplotlib.pyplot as plt
import numpy as np

def quadratic_model(time):
    a = 0.1
    b = -1
    c = 30
    temperature = a*(time**2) + b*time + c
    return temperature

def main():
    time_values = np.linspace(0, 10, 50)
    temperature_values = quadratic_model(time_values)

    plt.plot(time_values, temperature_values, label='Hard coded coefficients')
    plt.xlabel('Time')
    plt.ylabel('Temperature')
    plt.legend()
    plt.title('Weather modeling with quadratic equation (hard coded coefficients)')
    plt.show()

if __name__ == "__main__":
    main()

# %%
import matplotlib.pyplot as plt
import numpy as np

def quadratic_model(time, a, b, c):
    temperature = a*(time**2) + b*time + c
    return temperature

def main():
    a = float(input("Enter the value of a: "))
    b = float(input("Enter the value of b: "))
    c = float(input("Enter the value of c: "))

    time_values = np.linspace(0, 10, 50)
    temperature_values = quadratic_model(time_values, a, b, c)

    plt.plot(time_values, temperature_values, label='Quadratic Model')
    plt.xlabel('Time')
    plt.ylabel('Temperature')
    plt.legend()
    plt.title('Weather Modeling with Quadratic Equation')
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# Enter the value of a: 3
# Enter the value of b: 4
# Enter the value of c: 6

# %%
import matplotlib.pyplot as plt
import numpy as np

def quadratic_model(time, coefficients):
    temperature = {}
    for i in range(len(coefficients)):
      a, b, c = coefficients[i]
      temperature[i] = a*(time**2) + b*time + c
    return temperature

def main():
    coefficients = {
        0 : [0.2,1.5,15],
        1 : [0.5, 2 , 18],
        2 : [0.03 , 1 , 25]
    }
    time_values = np.linspace(0, 10, 50)
    temperature_values = quadratic_model(time_values, coefficients)
    for i in range(len(coefficients)):
      plt.plot(time_values, temperature_values[i], label='set' + str(i + 1) + " : " + ','.join(map(str , coefficients[i])))
    plt.xlabel('Time')
    plt.ylabel('Temperature')
    plt.legend()
    plt.title('Weather modeling with quadratic equation (coefficients hardcoded)')
    plt.show()

if __name__ == "__main__":
    main()

# %%
import numpy as np
import matplotlib.pyplot as plt

def quadratic_model1(time,a1,b1,c1):

    temp1=a1*(time**2)+b1*(time)+c1
    return temp1
def quadratic_model2(time):
      a2=0.1
      b2=-1
      c2=30

      temp2=a2*(time**2)+b2*(time)+c2
      return temp2
def main():
        time= np.arange(0,50,10)
        a1=float(input('enter a value: '))
        b1=float(input('enter b value: '))
        c1=float(input('enter c value: '))
        temp1 = quadratic_model1(time,a1,b1,c1)

        temp2 = quadratic_model2(time)
        plt.plot(time,temp1,label='user input coefficient',color='blue')
        plt.plot(time,temp2,label='hard_coded coefficient',color='green')

        plt.xlabel('time')
        plt.ylabel('temperature')
        plt.legend()
        plt.title('weather modeling with quadratic equation')
        plt.show()

if __name__ == '__main__':
        main()
# Out:
# enter a value: 0.4
# enter b value: 0.7
# enter c value: 1

# %%
import matplotlib.pyplot as plt
import numpy as np

def quadratic_model(time, a, b, c):
    temperature = a * (time ** 2) + b * time + c
    return temperature

def main():
    try:
        with open("2.txt", "r") as file:
            n = file.read().split()
            a = float(n[0])
            b = float(n[1])
            c = float(n[2])

        time_values = np.linspace(0, 10, 50)
        temperature_hardcoded = quadratic_model(time_values, a, b, c)

        plt.plot(time_values, temperature_hardcoded, label='File-defined n')
        plt.xlabel('Time')
        plt.ylabel('Temperature')
        plt.legend()
        plt.title('Weather modeling with quadratic equation (File-defined n)')
        plt.show()

    except FileNotFoundError:
        print("Error: 'n.txt' file not found. Please create it with the coefficients on separate lines.")

if __name__ == "__main__":
    main()

# %%
import matplotlib.pyplot as plt
import numpy as np

def quadratic_model(time, a, b, c):
    temperature = a * (time**2) + b * time + c
    return temperature

def main():
    num_sets = int(input("Enter the number of coefficient sets: "))

    coefficient_sets = []
    for i in range(num_sets):
        print(f"\nCoefficient set {i + 1}:")
        a = float(input("Enter the value of a: "))
        b = float(input("Enter the value of b: "))
        c = float(input("Enter the value of c: "))
        coefficient_sets.append((a, b, c))

    time_values = np.linspace(0, 10, 100)
    plt.figure()

    for i, (a, b, c) in enumerate(coefficient_sets):
        temperature = quadratic_model(time_values, a, b, c)
        plt.plot(time_values, temperature, label=f'Set {i+1}: a={a},b={b}, c={c}')

    plt.xlabel('Time')
    plt.ylabel('Temperature')
    plt.legend()
    plt.title('Weather Modelling with Quadratic Equation (Multiple Sets of Coefficients)')

    # Disable grid
    plt.grid(False)

    plt.show()

if __name__ == '__main__':
    main()
# Out:
# Enter the number of coefficient sets: 3
#
# Coefficient set 1:
# Enter the value of a: 12
# Enter the value of b: 45
# Enter the value of c: 30
#
# Coefficient set 2:
# Enter the value of a: 25
# Enter the value of b: 14
# Enter the value of c: 16
#
# Coefficient set 3:
# Enter the value of a: 23
# Enter the value of b: 21
# Enter the value of c: 20
